# %% [markdown]
# ---
# ## Actividad Entregable
# 1. Leer un archivo del formato de su elección sobre cualquier temática
# 2. Muestre la forma (SHAPE), información general (df.info()) y estadisticas descriptivas (df.describe()) del dataset
# 3. Genere un nuevo dataset aplicando un filtro sobre los datos originales
# 4. Genere un nuevo dataset aplicando un ordenamiento sobre los datos originales

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Lectura de archivo csv
top_clubes = pd.read_csv('/content/drive/MyDrive/Clubes_futbol.zip'
              ,encoding='utf-8'
              ,sep = ",")
top_clubes.head(10)
# Out:
#                   Club     Competition   Age  Squad_size Market_value  \
# 0      Manchester City  Premier League  27.2          23      €1.05bn
# 1  Paris Saint-Germain         Ligue 1  26.1          35     €997.75m
# 2    Manchester United  Premier League  28.0          28     €937.25m
# 3           Chelsea FC  Premier League  26.8          27     €882.50m
# 4         Liverpool FC  Premier League  27.0          27     €879.50m
# 5        Bayern Munich      Bundesliga  25.9          26     €852.90m
# 6          Real Madrid          LaLiga  27.2          27     €793.50m
# 7   Atlético de Madrid          LaLiga  28.1          22     €755.20m
# 8    Tottenham Hotspur  Premier League  25.5          24     €697.00m
# 9         FC Barcelona          LaLiga  25.3          29     €677.00m
#
#   Market_value_of_players MV_Top_18_players Share_of_MV
# 0                 €45.75m          €988.00m      93.9 %
# 1                 €28.51m          €889.00m      89.1 %
# ...

# %%
# Forma (SHAPE), información general (df.info()) y estadisticas descriptivas (df.describe()) del dataset

print('Shape / Forma:', top_clubes.shape)
top_clubes.info()
top_clubes.describe()
# Out:
# Shape / Forma: (100, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Club                     100 non-null    object
#  1   Competition              100 non-null    object
#  2   Age                      100 non-null    float64
#  3   Squad_size               100 non-null    int64
#  4   Market_value             100 non-null    object
#  5   Market_value_of_players  100 non-null    object
#  6   MV_Top_18_players        100 non-null    object
#  7   Share_of_MV              100 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.4+ KB
#              Age  Squad_size
# count  100.00000   100.00000
# mean    26.30800    27.54000
# std      1.39499     2.87244
# min     23.10000    21.00000
# 25%     25.40000    26.00000
# 50%     26.25000    27.00000
# 75%     27.42500    29.00000
# ...

# %%
# Nuevo dataset aplicando un filtro sobre los datos originales
print("Columnas disponibles:", top_clubes.columns)
# Out:
# Columnas disponibles: Index(['Club', 'Competition', 'Age', 'Squad_size', 'Market_value',
#        'Market_value_of_players', 'MV_Top_18_players', 'Share_of_MV'],
#       dtype='object')

# %%
print("Equipos Ingleses")
top_clubes[top_clubes['Competition'] == 'Premier League']
# Out:
# Equipos Ingleses
#                        Club     Competition   Age  Squad_size Market_value  \
# 0           Manchester City  Premier League  27.2          23      €1.05bn
# 2         Manchester United  Premier League  28.0          28     €937.25m
# 3                Chelsea FC  Premier League  26.8          27     €882.50m
# 4              Liverpool FC  Premier League  27.0          27     €879.50m
# 8         Tottenham Hotspur  Premier League  25.5          24     €697.00m
# 13           Leicester City  Premier League  26.9          28     €550.10m
# 14               Arsenal FC  Premier League  25.3          26     €548.50m
# 18               Everton FC  Premier League  27.8          26     €433.75m
# 22              Aston Villa  Premier League  25.7          24     €408.30m
# 23  Wolverhampton Wanderers  Premier League  26.3          24     €391.10m
# 25          West Ham United  Premier League  28.8          24     €353.25m
# ...

# %%
# Nuevo dataset aplicando un ordenamiento sobre los datos originales
top_clubes.sort_values(by='Market_value_of_players',ascending=True)
# Out:
#                         Club     Competition   Age  Squad_size Market_value  \
# 36                  FC Porto       Liga Bwin  26.7          26     €265.00m
# 35                LOSC Lille         Ligue 1  25.4          26     €272.00m
# 38              Leeds United  Premier League  24.9          24     €252.70m
# 31  Borussia Mönchengladbach      Bundesliga  25.4          28     €300.00m
# 28            Olympique Lyon         Ligue 1  25.5          29     €348.50m
# ..                       ...             ...   ...         ...          ...
# 41    Brighton & Hove Albion  Premier League  25.8          26     €248.10m
# 40            ACF Fiorentina         Serie A  26.9          26     €248.80m
# 42          Newcastle United  Premier League  28.2          25     €241.40m
# 34                SL Benfica       Liga Bwin  27.1          29     €285.50m
# 30                  SS Lazio         Serie A  27.5          33     €326.60m
#
#    Market_value_of_players MV_Top_18_players Share_of_MV
# ...
